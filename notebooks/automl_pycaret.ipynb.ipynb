# %%
from pycaret.classification import *

# %%
import pandas as pd

# Load the preprocessed churn dataset
df = pd.read_csv('/Users/darshanr/Documents/automl-churn-pipeline/data/cleaned_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
import pandas as pd

# Load the cleaned data
df = pd.read_csv('/Users/darshanr/Documents/automl-churn-pipeline/data/cleaned_churn.csv')

# %%
from pycaret.classification import *

s = setup(
    data=df,
    target='Churn',
    session_id=42,
    normalize=True,
    verbose=False
)

# %%
# Automatically train and compare top classification models
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_7767f th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predictions = predict_model(best_model)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9c107">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c107_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9c107_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9c107_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9c107_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9c107_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9c107_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9c107_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9c107_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c107_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c107_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
# ...

# %%
save_model(best_model, 'best_churn_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['SeniorCitizen', 'tenure',
#                                               'MonthlyCharges', 'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty...
#                                                                min_samples_leaf=20,
# ...
